# %%
import pandas as pd

qna_list = pd.read_csv('qna_total_list_210702.csv')
qna_list.head()

qna_list.isna().sum()

qna_list = qna_list.dropna()

qna_list.isna().sum()

qna_list['q_length'] = qna_list['q_content'].str.len()

qna_list
# Out:
#      qna_no             q_title  \
# 1      4463     신용회복중 활부나 리스 가능
# 3      4451                  제차
# 4      4447     만 21세 이상 보험 넣으면
# 5      4446               전기화물차
# 6      4445                  상담
# ...     ...                 ...
# 1061     93             글이안써집니다
# 1062     64           상담신청 합니다.
# 1063     63  이벤트 오류 문의드려요 고쳐주세요
# 1064     62              상담 테스트
# 1065     53                 테스트
#
#                                               q_content  \
# 1     신용회복위원회에 22년 1월에 금액을 납부 해야하는 상황인데 차량이 8월 정도 필요...
# 3                                         카이런 매물 내놓고  ㅈ
# 4                대충 달에 얼마정도 들까요?? 그리고 기본옵션들 뭐뭐 들어있나요!??
# 5                              1톤 전기 화물차에  대하여  상담코져합니다
# 6                                                  상담요청
# ...                                                 ...
# 1061  <p>https://www.reborncar.co.kr/event/WUEV01000...
# 1062  <p><a href="https://www.reborncar.co.kr/smartb...
# 1063  <p>https://www.reborncar.co.kr/event/WUEV01000...
# 1064                                  <p>문의 테스트입니다.</p>
# 1065                                         <p>테스트</p>
#
#                                               a_content       q_date  \
# 1     <p>안녕하세요 김시온 고객님.</p><p>신용회복중 할부 또는 리스진행이 어려운점...   오후 6:03:26
# 3     <p>안녕하세요 권낙현 고객님.</p><p>문의주시는 내용이 대차구매가 맞으실까요?...  오전 10:25:26
# 4     <p>안녕하세요 김민성 고객님.</p><p>문의주신 올 뉴K3 202무6461 차량...   오전 5:01:25
# 5     <p>안녕하세요 이광호 고객님.</p><p>문의주신 전기화물차 확인하였으나, 아직은...   오후 9:33:58
# 6     <p>안녕하세요 이범규 고객님.</p><p>문의주신 올 뉴모닝 31조8029 차량 ...   오후 8:49:19
# ...                                                 ...          ...
# 1061  <p>안녕하세요, 이봉기 고객님.&nbsp;</p><p>끝까지 책임지는 리본카 고객...   오후 6:08:30
# 1062                                    <p>사세요~ 빨리~</p>  오전 10:50:05
# 1063  <p>안녕하세요, 하점숙 고객님.&nbsp;</p><p>끝까지 책임지는 리본카 고객...   오전 2:00:01
# 1064  <p>테스트에 대한 답변 테스트입니다.</p><p>답변이 올바르게 전달되는지 확인하...  오후 10:03:40
# 1065                                       <p>감사합니다</p>  오전 10:27:21
#
#                        manager       a_date  q_length
# 1                    kimjr1201   오전 9:18:25        76
# 3                    kimjr1201  오전 10:47:04        13
# 4                    kimjr1201   오전 9:13:36        38
# 5                    kimjr1201   오전 9:44:43        24
# 6                    kimjr1201   오전 9:01:38         4
# ...                        ...          ...       ...
# 1061  hanmh1028@autoplus.co.kr  오전 11:07:00       110
# 1062                 adminuser  오전 10:54:16       172
# 1063  hanmh1028@autoplus.co.kr  오전 10:42:54       153
# 1064                 adminuser  오후 10:08:07        17
# 1065                 adminuser  오전 10:27:55        10
#
# [982 rows x 8 columns]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.hist(qna_list['q_length'])
# Out:
# (array([942.,  26.,   7.,   2.,   2.,   1.,   0.,   1.,   0.,   1.]),
#  array([1.0000e+00, 2.3620e+02, 4.7140e+02, 7.0660e+02, 9.4180e+02,
#         1.1770e+03, 1.4122e+03, 1.6474e+03, 1.8826e+03, 2.1178e+03,
#         2.3530e+03]),
#  <BarContainer object of 10 artists>)
